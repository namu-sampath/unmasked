# %%
import pandas as pd
import numpy as np
import re 
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator

# %%
tables = pd.read_html("https://en.wikipedia.org/wiki/List_of_serial_killers_in_the_United_States#Identified_serial_killers")

# %%
serial_killers = tables[0]
serial_killers
# Out:
#                          Name Years active Proven victims Possible victims  \
# 0                 Ables, Tony    1970–1990              4               4+
# 1          Acevedo, Francisco    1989–1996              3                3
# 2         Adams, Edward James    1920–1921              7                7
# 3                 Agrue, John    1966–1982              3               3+
# 4           Albanese, Charles    1980–1981              3                3
# ..                        ...          ...            ...              ...
# 707           Wooten, Charles    1969–1993              3                3
# 708  Wright, Douglas Franklin    1969–1991              7               7+
# 709           Wuornos, Aileen    1989–1990              7                7
# 710         Yates, Robert Lee    1975–1998             13              18+
# 711          Zarinsky, Robert    1958–1974              2               10
#
#                                                 Status  \
# 0    Sentenced to death; commuted to life imprisonment
# 1                        Sentenced to 75 years to life
# 2                     Killed by police during shootout
# 3                                         Died in 2009
# 4                                        Executed 1995
# ..                                                 ...
# 707                     Sentenced to life imprisonment
# 708                                      Executed 1996
# 709                                      Executed 2002
# 710  Sentenced to death; commuted to life imprisonment
# 711                                     Died in prison
#
#                                                  Notes Source(s)
# 0    Murdered robbery victim in 1970, and at least ...       [4]
# 1    Strangled three prostitutes in New York betwee...       [5]
# 2     Murdered seven people, including three policemen       [6]
# 3    Killed his sister-in-law in Illinois; paroled ...       [7]
# 4    Poisoned family members with arsenic in Fox La...       [8]
# ..                                                 ...       ...
# 707  Killed two gas station attendants in Fort Wort...     [771]
# 708  First criminal executed by lethal injection in...     [772]
# 709  Known as the "Damsel of Death"; shot seven men...     [773]
# 710   Targeted women in and around Spokane, Washington     [774]
# 711              Preyed on teenage girls in New Jersey     [775]
#
# [712 rows x 7 columns]

# %%
serial_killers.columns = serial_killers.columns.str.lower()
serial_killers
# Out:
#                          name years active proven victims possible victims  \
# 0                 Ables, Tony    1970–1990              4               4+
# 1          Acevedo, Francisco    1989–1996              3                3
# 2         Adams, Edward James    1920–1921              7                7
# 3                 Agrue, John    1966–1982              3               3+
# 4           Albanese, Charles    1980–1981              3                3
# ..                        ...          ...            ...              ...
# 707           Wooten, Charles    1969–1993              3                3
# 708  Wright, Douglas Franklin    1969–1991              7               7+
# 709           Wuornos, Aileen    1989–1990              7                7
# 710         Yates, Robert Lee    1975–1998             13              18+
# 711          Zarinsky, Robert    1958–1974              2               10
#
#                                                 status  \
# 0    Sentenced to death; commuted to life imprisonment
# 1                        Sentenced to 75 years to life
# 2                     Killed by police during shootout
# 3                                         Died in 2009
# 4                                        Executed 1995
# ..                                                 ...
# 707                     Sentenced to life imprisonment
# 708                                      Executed 1996
# 709                                      Executed 2002
# 710  Sentenced to death; commuted to life imprisonment
# 711                                     Died in prison
#
#                                                  notes source(s)
# 0    Murdered robbery victim in 1970, and at least ...       [4]
# 1    Strangled three prostitutes in New York betwee...       [5]
# 2     Murdered seven people, including three policemen       [6]
# 3    Killed his sister-in-law in Illinois; paroled ...       [7]
# 4    Poisoned family members with arsenic in Fox La...       [8]
# ..                                                 ...       ...
# 707  Killed two gas station attendants in Fort Wort...     [771]
# 708  First criminal executed by lethal injection in...     [772]
# 709  Known as the "Damsel of Death"; shot seven men...     [773]
# 710   Targeted women in and around Spokane, Washington     [774]
# 711              Preyed on teenage girls in New Jersey     [775]
#
# [712 rows x 7 columns]

# %%
len(serial_killers)
# Out:
# 712

# %%
# dataframe of serial killers with the most possible victims (descending order)
possible_victims = serial_killers.sort_values(by=['possible victims'], ascending = False)
possible_victims
# Out:
#                         name years active proven victims possible victims  \
# 410       LaLaurie, Delphine         1834              ?                ?
# 423           Little, Samuel    1970–2005             61              93+
# 559            Ridgway, Gary    1982–1998             49              90+
# 135            Cook, Anthony    1973–1981              9               9+
# 15   Anderson, Stephen Wayne    1973–1980              9               9+
# ..                       ...          ...            ...              ...
# 297  Harris, Michael Darnell    1981–1982              4               10
# 416          Lewingdon, Gary    1977–1978             10               10
# 382           Kemper, Edmund    1964–1973             10               10
# 711         Zarinsky, Robert    1958–1974              2               10
# 5                        NaN          NaN            NaN              NaN
#
#                              status  \
# 410           Died in Paris, France
# 423                  Died in prison
# 559  Sentenced to life imprisonment
# 135  Sentenced to life imprisonment
# 15                    Executed 2002
# ..                              ...
# 297  Sentenced to life imprisonment
# 416                  Died in prison
# 382  Sentenced to life imprisonment
# 711                  Died in prison
# 5                               NaN
#
#                                                  notes     source(s)
# 410  New Orleans socialite who tortured and maimed ...         [454]
# 423  Known as "The Choke-and-Stroke Killer"; transi...    [470][471]
# 559  Known as "The Green River Killer"; targeted se...         [614]
# 135   Committed crimes with his brother Nathaniel Cook         [145]
# 15     Murdered people in Utah, Nevada, and California  [19][20][21]
# ..                                                 ...           ...
# 297  Raped, beat and strangled elderly women across...         [329]
# 416  Together with brother Thaddeus Lewingdon, know...    [462][463]
# 382  Known as "The Co-Ed Killer"; murdered his gran...         [419]
# 711              Preyed on teenage girls in New Jersey         [775]
# 5                                                  NaN           NaN
#
# [712 rows x 7 columns]

# %%
possible_victims.head(10)
# Out:
#                         name years active proven victims possible victims  \
# 410       LaLaurie, Delphine         1834              ?                ?
# 423           Little, Samuel    1970–2005             61              93+
# 559            Ridgway, Gary    1982–1998             49              90+
# 135            Cook, Anthony    1973–1981              9               9+
# 15   Anderson, Stephen Wayne    1973–1980              9               9+
# 167           Davis, Girvies    1978–1979              4               9+
# 320               Hill, Ivan    1979–1994              9               9+
# 546             Rees, Melvin    1957–1959              5               9+
# 519          Pierce, William    1970–1971              9               9+
# 557     Richards, Stephen D.    1876–1878              9               9+
#
#                              status  \
# 410           Died in Paris, France
# 423                  Died in prison
# 559  Sentenced to life imprisonment
# 135  Sentenced to life imprisonment
# 15                    Executed 2002
# 167                   Executed 1995
# 320              Sentenced to death
# 546                  Died in prison
# 519                  Died in prison
# 557                   Executed 1879
#
#                                                  notes  \
# 410  New Orleans socialite who tortured and maimed ...
# 423  Known as "The Choke-and-Stroke Killer"; transi...
# 559  Known as "The Green River Killer"; targeted se...
# 135   Committed crimes with his brother Nathaniel Cook
# 15     Murdered people in Utah, Nevada, and California
# 167  Accomplice of Richard Holman; killed robbery w...
# 320  Known as "The 60 Freeway Killer"; responsible ...
# 546                           Known as "The Sex Beast"
# 519  One of his victims was the daughter of a South...
# 557  Known as "The Nebraska Fiend", Richards murder...
#
#                     source(s)
# 410                     [454]
# 423                [470][471]
# 559                     [614]
# 135                     [145]
# 15               [19][20][21]
# 167                     [181]
# 320                     [353]
# 546  [13][unreliable source?]
# 519                     [572]
# 557                     [612]

# %%
years_active = serial_killers.sort_values(by='years active')

# %%
years_active.head(10)
# Out:
#                    name years active proven victims possible victims  \
# 448       Mason, Samuel    1797–1803             20              20+
# 295      Harpe Brothers    1797–1804             39              50+
# 96        Cannon, Patty    1802–1829              4              25+
# 274       Green, Samuel    1817–1821              2               2+
# 410  LaLaurie, Delphine         1834              ?                ?
# 580  Rulloff, Edward H.    1844–1870              3                5
# 288       Hall, Andreas    1847–1848              3                3
# 311         Helm, Boone    1850–1864             11              11+
# 201  Evans, Franklin B.    1850–1872              2               5+
# 705      Wood, Isaac L.         1855              3                3
#
#                                                 status  \
# 448  Killed/Died from injuries received during a sh...
# 295       Lynched 1799 (Micajah) Executed 1804 (Wiley)
# 96                       Died in prison awaiting trial
# 274                                      Executed 1822
# 410                              Died in Paris, France
# 580                                      Executed 1871
# 288                                      Executed 1849
# 311                                      Executed 1864
# 201                                      Executed 1874
# 705                                      Executed 1858
#
#                                                  notes   source(s)
# 448  River pirate associated with the Harpe brother...       [503]
# 295  Brothers or cousins; America's first known ser...       [327]
# 96   Gang leader who kidnapped slaves and free blac...       [103]
# 274               Known as "The Terror of New England"       [308]
# 410  New Orleans socialite who tortured and maimed ...       [454]
# 580  Known as "The Genius Killer"; Canadian-born do...  [634][635]
# 288  Prolific thief who killed three people during ...       [321]
# 311  Known as "The Kentucky Cannibal"; mountain man...  [343][344]
# 201  Known as "The Northwood Murderer"; vagrant who...       [226]
# 705  Poisoned his wife, brother and sister-in-law f...       [769]

# %%
unique_values = serial_killers['status'].unique()
# print the unique values
for value in unique_values:
    print(value)
# Out:
# Sentenced to death; commuted to life imprisonment
# Sentenced to 75 years to life
# Killed by police during shootout
# Died in 2009
# Executed 1995
# nan
# Died in prison awaiting execution
# Executed 2010
# Executed 1942
# Died in prison
# Sentenced to death
# Sentenced to life imprisonment
# Executed 2002
# Sentenced to 61 years to life in prison
# Died in Connecticut Hospital for the Insane
# Executed 1999
# Committed suicide to avoid arrest
# Executed 1984
# 40 years imprisonment
# Died in prison before execution
# Executed 1926
# Murdered in police custody
# Committed suicide prior to execution
# Executed 2005
# Executed 1951
# Unknown
# Executed 1920
# Executed 1949
# Executed 1988
# Sentenced to 50 years to life
# Sentenced to 40 years in prison
# Died while incarcerated at Henry Ford Allegiance Health
# Executed 2016
# Committed suicide in custody
# Executed 1996
# Executed 2019
# Awaiting sentencing
# Killed by intended victims
# Executed 1984/1985 (Linwood and James) Sentenced to life imprisonment (Anthony)
# Executed 1998
# Sentenced to 150 years to life
# Died in an intentional motorcycle crash before being apprehended
# Executed 1989
# Committed suicide to avoid apprehension
# Executed 1962
# Died in North Dakota State Hospital
# Died in prison awaiting trial
# Executed 1870
# Executed 2000
# Executed 1943
# Executed 2011
# Committed suicide in prison
# Executed 2003
# Executed 2013
# Murdered in prison by unknown assailant
# Sentenced to 70 years
# Died in 1944
# Executed 1985
# Executed 1957
# Released in 2018
# Released to a nursing home shortly before her death
# Killed by accomplice Elmer Wayne Henley
# Released in 2013
# Murdered by inmate Christopher Scarver
# Died in a car crash prior to apprehension
# Died before trial
# Sentenced to death; released in 2019
# Executed 1993
# Executed 2008
# Executed 1959
# Executed 1868
# Committed suicide before trial
# Killed by Tom Tobin
# Died in prison; murdered by a fellow death row inmate
# Executed 1874
# Committed suicide after escaping police custody
# Died of AIDS-related complications in 1994 while awaiting execution
# Killed by intended victim
# Executed 2009
# Died in a plane crash
# Executed 1936
# Accidental drowning after escaping from a mental hospital
# Executed 1994
# Died awaiting execution
# Executed 1933
# Executed 2018
# Executed 1991
# Executed 1948
# Incarcerated for 120 years
# Died while incarcerated at Mendota Mental Health Institute
# Died in Missouri State Hospital #4
# Executed 1953
# Executed 2012
# Executed 2017
# Executed 1997
# Executed 1822
# Died before apprehension
# Executed 1992
# Executed 1938
# Executed 1849
# Died in Matteawan State Hospital for the Criminally Insane
# Executed 1901
# Lynched 1799 (Micajah) Executed 1804 (Wiley)
# Sentenced to 94 years in prison
# Sentenced to three concurrent terms of life in prison; killed by prison inmate James Elliott
# Executed 1928
# Executed 1895
# Died in 1938
# Executed 1864
# Executed 2014
# Committed suicide prior to release
# Died while a fugitive
# Executed 1896
# Executed 2020
# Sentenced to life in prison
# Executed in 2000
# Sentenced to 5 years to life in prison
# 6 years and 3 months; released with time served
# Executed 1941
# Released in 2020
# Sentenced to 190 years in prison
# Sentenced to 99 years in prison
# Executed 1915
# Sentenced to 60 years in prison
# Murdered in prison by two fellow inmates
# Killed by vigilantes
# Killed in prison by fellow inmate
# Sentenced to 70 years in prison
# Escaped from prison 1969
# Executed 1904
# Sentenced to two life sentences
# Sentenced to 22 years in prison
# Killed by police attempting to escape from custody
# Released in 2019
# Executed 1929
# Executed 2015
# Executed 2004
# Died in Paris, France
# Sentenced to 50 years
# Murdered by inmate while awaiting trial
# Died from accidental self-inflicted injuries
# Executed 1961
# Died in prison.
# Died in a federal medical center
# Died in a mental hospital
# Life imprisonment without parole (overturned on May 26, 2017); Supreme Court of the United States heard the case on October 16, 2019.[487]
# In custody
# Sentenced to 45 to 70 years in prison
# Sentenced to 66 years in prison
# Murdered in prison
# Killed/Died from injuries received during a shoot-out
# 12 years
# Executed 1958
# Incarcerated
# Sentenced to 28 to 48 years in prison
# Sentenced to life imprisonment without parole
# Sentenced to 15–30 years in prison
# Executed 1886
# Executed 1939
# Sentenced to 20 years probation in 1998
# Executed 1930
# Executed 1947
# Sentenced to death; commuted to 120 years imprisonment
# Executed 1876
# Executed 1932
# Executed 2006
# Executed 1879
# Incarcerated for 203 years to life
# Killed by police during apprehension
# Executed 1935
# Executed 1956
# Serving 25 years to life on a conviction for check kiting under a third strike law
# Executed 1871
# Sentenced to 41 years in prison
# Supposedly died while incarcerated at Taunton Lunatic Asylum
# Murdered in prison by fellow inmate Vincent Rivera
# Murdered in prison by unknown assailants
# Murdered in prison by a fellow inmate
# Sentenced to death; commuted to life
# Executed 1899
# Released in 1941
# Executed 1990
# Died in 2001
# Found not guilty by reason of insanity and confined to Saint Elizabeths Hospital
# Executed 1960
# Sentenced to 20 years to life, released on August 21, 2018
# Found not guilty by reason of insanity and committed for life to the Taunton State Hospital
# Died in 1913
# Executed 1908
# Sentenced to 160 years in prison
# Sentenced to 150 years to life in prison
# Executed 1889
# Killed by fellow death row inmates
# Executed 1891
# Sentenced to eight to 25 years
# Incarcerated 20–40 years
# Executed 1963
# Executed 1858
# Sentenced to life imprisonment plus 165 years

# %%
# reorganizing 'status' column for all values that include 'executed [year]'
serial_killers['status'] = np.where(serial_killers['status'].str.contains('Executed'), 'Executed', serial_killers['status'])

# %%
# calculate the counts for each unique value in the 'Status' column
category_counts = serial_killers['status'].value_counts()

# Print the top 15 values
print(category_counts.head(15))
# Out:
# status
# Sentenced to life imprisonment                       168
# Executed                                             167
# Died in prison                                       107
# Sentenced to death                                    69
# Sentenced to death; commuted to life imprisonment     20
# Died in prison awaiting execution                     18
# Committed suicide to avoid arrest                     17
# Committed suicide in prison                           10
# Committed suicide in custody                           6
# Committed suicide prior to execution                   6
# Unknown                                                6
# Sentenced to 75 years to life                          4
# Committed suicide before trial                         4
# Released in 2020                                       3
# Incarcerated                                           2
# Name: count, dtype: int64

# %%
# Convert 'Proven victims' column to numeric data type, ignoring errors
serial_killers['proven victims'] = pd.to_numeric(serial_killers['proven victims'], errors='coerce')

# Group by serial killer and calculate the sum of proven victims
killer_victim_counts = serial_killers.groupby('name')['proven victims'].sum()

# Sort the counts in descending order
killer_victim_counts = killer_victim_counts.sort_values(ascending=False)

# Print the sorted counts
print(killer_victim_counts.head(20))
# Out:
# name
# Little, Samuel        61.0
# Ridgway, Gary         49.0
# Harpe Brothers        39.0
# Harvey, Donald        37.0
# Gacy, John Wayne      33.0
# Espinosa, Felipe      32.0
# Bundy, Ted            28.0
# Corll, Dean           28.0
# Corona, Juan          25.0
# Gunness, Belle        25.0
# Dominique, Ronald     23.0
# Bartlett, Polly       22.0
# Nelson, Earle         22.0
# Stano, Gerald         22.0
# Watts, Carl Eugene    22.0
# Kearney, Patrick      21.0
# Eyler, Larry          21.0
# Bonin, William        21.0
# Mason, Samuel         20.0
# Kokoraleis, Andrew    18.0
# Name: proven victims, dtype: float64

# %%
# calculating how many of these locations were similar (serial killer hotspots?)
# define a regex pattern to match state names (add more if needed)
state_pattern = r'\b((?:Alabama|Alaska|Arizona|Arkansas|California|Colorado|Connecticut|Delaware|Florida|Georgia|Hawaii|Idaho|Illinois|Indiana|Iowa|Kansas|Kentucky|Louisiana|Maine|Maryland|Massachusetts|Michigan|Minnesota|Mississippi|Missouri|Montana|Nebraska|Nevada|New Hampshire|New Jersey|New Mexico|New York|North Carolina|North Dakota|Ohio|Oklahoma|Oregon|Pennsylvania|Rhode Island|South Carolina|South Dakota|Tennessee|Texas|Utah|Vermont|Virginia|Washington|West Virginia|Wisconsin|Wyoming))\b'

# extract state names from 'Notes' column and calculate the counts
state_counts = serial_killers['notes'].str.extractall(state_pattern, flags=re.IGNORECASE).value_counts()

# print the counts for each state
print(state_counts)
# Out:
# California        65
# New York          34
# Florida           34
# Texas             29
# Washington        19
# Missouri          18
# Ohio              16
# Illinois          16
# Michigan          15
# Oregon            15
# New Jersey        13
# Pennsylvania      11
# Kansas            10
# North Carolina    10
# Massachusetts     10
# Indiana            9
# Virginia           9
# South Carolina     9
# Kentucky           8
# Colorado           7
# Nevada             7
# Utah               7
# Georgia            7
# Louisiana          6
# Connecticut        6
# Arizona            5
# Maine              5
# Nebraska           5
# Maryland           5
# Tennessee          4
# Alaska             4
# Oklahoma           4
# West Virginia      4
# New Mexico         3
# Arkansas           3
# Rhode Island       3
# Wisconsin          3
# Alabama            2
# North Dakota       2
# Montana            2
# Minnesota          2
# Delaware           2
# Wyoming            2
# New Hampshire      1
# Mississippi        1
# Iowa               1
# Idaho              1
# Hawaii             1
# Name: count, dtype: int64

# %%
# Out:
# Series([], dtype: int64)
